# %%
# Read In Dependencies
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy
from matplotlib import pyplot as plt
from scipy.stats import boxcox

#Read In Data
df_train = pd.read_csv('2016_cleaned.csv')

# Set Randomization Defaults
np.random.seed(21)

target = 'logerror'
pid = 'parcelid'

# Set Aesthetic Defaults
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %%
#Helper Functions
def run_multiple_regression_ols(df, X_list, print_output = False):

    X = sm.add_constant(df.loc[:, X_list]) # Predictor Matrix: IV + Constant
    y = df.Y # Prediction Targets

    # Fit, summarize OLS regression
    model = sm.OLS(y, X)
    result = model.fit()
    
    if print_output == True:
        
        print(result.summary())
        
    resids = result.resid
    preds = result.predict(X)
    
    return result, resids, preds


def backward_regression(X, y,initial_list=[], threshold_in=0.01, threshold_out = 0.05, verbose=True):
    included=list(X.columns)
    
    i = 1
    
    while True:
        i += 1
        changed=False
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
            if verbose:
                print(f'Feature Dropped: {worst_feature} (p = {worst_pval:.3f})')
        if not changed:
            break
    return included

def normal_probability_plot(result, resids):
    
    resid_df = pd.DataFrame(resids, columns = ['resid'])
    resid_df = resid_df.sort_values(by = 'resid').reset_index(drop = True).reset_index().rename({'index':'k'}, axis = 1)
    resid_df.k = resid_df.k + 1
    resid_df['expected_value'] = resid_df.apply(lambda x: np.sqrt(result.mse_resid) * scipy.stats.norm().ppf((x.k - .375)/(len(resid_df) + .25)), axis = 1)

    fig = plt.scatter(resid_df.expected_value, resid_df.resid)

    plt.xlabel('Expected')
    plt.ylabel('Residual')
    plt.title('Normal Probability Plot')
    
    plt.show()
    
def plot_resid_pred(resid, pred):
    plt.scatter(pred, resid, s = 2.5)
    plt.xlabel(pred.name)
    plt.ylabel('Residual Value')
    plt.title('Residual Values v. ' + pred.name)
    plt.axhline(color = 'black', linestyle = 'dashed')
    plt.show()

# %% [markdown]
# # EDA: Normality of Target, Predictors
# ## Trainging Target

# %%
_, l = boxcox(df_train.logerror + np.abs(df_train.logerror.min()) + .000001) 
print(f'Y Box-Cox lambda: {l:.3f}')
# Out:
# Y Box-Cox lambda: 0.970

# %% [markdown]
# ## Predictors

# %%
continuous_cols = [
    'bedroomcnt','buildingqualitytypeid','calculatedbathnbr','calculatedfinishedsquarefeet','fireplacecnt','lotsizesquarefeet','roomcnt','unitcnt','yearbuilt','structuretaxvaluedollarcnt','landtaxvaluedollarcnt'
    
]
    

for i in continuous_cols:
    print(i)
    var = df_train.loc[:, i]
    
    if var.min() <= 0:
        
        var = var + np.abs(var.min()) + .000001
        df_train.loc[:, i] = df_train.loc[:, i] + np.abs(df_train.loc[:, i].min()) + .000001
        
    _, l = boxcox(var) 
    
    df_train.loc[:, i] = np.power(df_train.loc[:, i], l)
    
    print(f' Box-Cox Transformed lambda: {l:.3f}')

print('')
print('QC: post-transformation Lambda Values')

for i in continuous_cols:
    print(i)
    var = df_train.loc[:, i]
    
    _, l = boxcox(var) 
    
    print(f' Box-Cox Transformed lambda: {l:.3f}')
    
# Censor Extreme values
for i in continuous_cols:
    var_mean = df_train.loc[:, i].mean()
    var_std = df_train.loc[:, i].std()
    
    df_train.loc[df_train.loc[:, i] < var_mean - 3 * var_std, i] = var_mean - 3 * var_std
    df_train.loc[df_train.loc[:, i] > var_mean + 3 * var_std, i] = var_mean + 3 * var_std
# Out:
# bedroomcnt
#  Box-Cox Transformed lambda: 0.680
# buildingqualitytypeid
#  Box-Cox Transformed lambda: 1.457
# calculatedbathnbr
#  Box-Cox Transformed lambda: 0.215
# calculatedfinishedsquarefeet
#  Box-Cox Transformed lambda: -0.149
# fireplacecnt
#  Box-Cox Transformed lambda: -0.670
# lotsizesquarefeet
#  Box-Cox Transformed lambda: -0.395
# roomcnt
#  Box-Cox Transformed lambda: -0.258
# unitcnt
#  Box-Cox Transformed lambda: -6.172
# yearbuilt
#  Box-Cox Transformed lambda: 11.583
# structuretaxvaluedollarcnt
#  Box-Cox Transformed lambda: 0.057
# landtaxvaluedollarcnt
#  Box-Cox Transformed lambda: 0.118
#
# QC: post-transformation Lambda Values
# bedroomcnt
#  Box-Cox Transformed lambda: 1.000
# buildingqualitytypeid
#  Box-Cox Transformed lambda: 1.000
# calculatedbathnbr
#  Box-Cox Transformed lambda: 1.000
# calculatedfinishedsquarefeet
#  Box-Cox Transformed lambda: 1.000
# fireplacecnt
#  Box-Cox Transformed lambda: 1.000
# lotsizesquarefeet
#  Box-Cox Transformed lambda: 1.000
# roomcnt
#  Box-Cox Transformed lambda: 1.000
# unitcnt
#  Box-Cox Transformed lambda: 1.000
# yearbuilt
#  Box-Cox Transformed lambda: 1.000
# structuretaxvaluedollarcnt
#  Box-Cox Transformed lambda: 1.000
# landtaxvaluedollarcnt
#  Box-Cox Transformed lambda: 1.000
# /Users/bennett/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:908: RuntimeWarning: overflow encountered in power
#   variance = np.var(data**lmb / lmb, axis=0)
# /Users/bennett/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:230: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /Users/bennett/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:233: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /Users/bennett/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py:1960: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)

# %% [markdown]
# # Prototyping
# ## Full Model

# %%
drop_cols = [
    'fips_6111.0','heatingorsystemtypeid_24.0','regionidcity_9840.0','propertylandusetypeid_275.0','propertycountylandusecode_96', # Arbitrary Category Labels dropped for intercept hardening
    'assessmentyear', # No Cardinality (singular valued feature)
    'yearbuilt'
]
df_train['Y'] = df_train.logerror
training_cols = [i for i in df_train.columns if i not in [pid, target,'transactiondate','Y','census_tract','censustractandblock']]
training_cols = [i for i in training_cols if i not in drop_cols]

# %%
result_full, resids_full, preds_full = run_multiple_regression_ols(df_train, training_cols, True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.160
# Date:                Tue, 12 Apr 2022   Prob (F-statistic):          2.29e-147
# Time:                        09:05:30   Log-Likelihood:                 37533.
# No. Observations:               89670   AIC:                        -7.453e+04
# Df Residuals:                   89402   BIC:                        -7.201e+04
# Df Model:                         267
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                
# propertycountylandusecode_1210     0.3623      0.099      3.655      0.000       0.168       0.557
# propertycountylandusecode_122      0.8257      0.125      6.629      0.000       0.582       1.070
# propertycountylandusecode_1222     0.3439      0.103      3.337      0.001       0.142       0.546
# propertycountylandusecode_1310     0.0141      0.191      0.074      0.941      -0.359       0.388
# propertycountylandusecode_1321     0.2148      0.183      1.172      0.241      -0.145       0.574
# propertycountylandusecode_1333     0.3872      0.236      1.642      0.101      -0.075       0.849
# propertycountylandusecode_135      0.8910      0.201      4.438      0.000       0.498       1.284
# propertycountylandusecode_1410    -0.7727      0.126     -6.139      0.000      -1.019      -0.526
# propertycountylandusecode_1421    -0.7575      0.163     -4.644      0.000      -1.077      -0.438
# propertycountylandusecode_1432    -0.8829      0.163     -5.412      0.000      -1.203      -0.563
# propertycountylandusecode_1720     0.4849      0.117      4.145      0.000       0.256       0.714
# propertycountylandusecode_1722    -2.4338      0.189    -12.909      0.000      -2.803      -2.064
# propertycountylandusecode_34       0.8235      0.125      6.607      0.000       0.579       1.068
# propertycountylandusecode_38       1.1477      0.149      7.720      0.000       0.856       1.439
# propertycountylandusecode_73      -0.0963      0.167     -0.578      0.564      -0.423       0.231
# propertylandusetypeid_31.0        -1.5322      0.189     -8.124      0.000      -1.902      -1.163
# propertylandusetypeid_246.0       -1.5310      0.189     -8.088      0.000      -1.902      -1.160
# propertylandusetypeid_247.0       -1.2827      0.226     -5.680      0.000      -1.725      -0.840
# propertylandusetypeid_248.0       -0.3724      0.199     -1.876      0.061      -0.761       0.017
# propertylandusetypeid_260.0       -1.1474      0.178     -6.448      0.000      -1.496      -0.799
# propertylandusetypeid_261.0       -1.1624      0.174     -6.687      0.000      -1.503      -0.822
# propertylandusetypeid_263.0       -0.2185      0.255     -0.856      0.392      -0.719       0.282
# propertylandusetypeid_264.0       -0.8301      0.112     -7.430      0.000      -1.049      -0.611
# propertylandusetypeid_265.0       -0.5645      0.087     -6.504      0.000      -0.735      -0.394
# propertylandusetypeid_266.0       -1.1613      0.174     -6.678      0.000      -1.502      -0.820
# propertylandusetypeid_267.0       -0.6102      0.081     -7.500      0.000      -0.770      -0.451
# propertylandusetypeid_269.0       -1.1764      0.177     -6.653      0.000      -1.523      -0.830
# fips_6037.0                        0.1462      0.069      2.124      0.034       0.011       0.281
# fips_6059.0                       -0.7928      0.120     -6.602      0.000      -1.028      -0.557
# ==============================================================================
# Omnibus:                    65900.093   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         66424554.449
# Skew:                           2.174   Prob(JB):                         0.00
# Kurtosis:                     136.265   Cond. No.                     2.06e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.05e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Model Diagnostics

# %%
for column in [i for i in training_cols if i in continuous_cols]:
    
    plot_resid_pred(resids_full, df_train[column])

# %%
normal_probability_plot(result_full, resids_full)

# %% [markdown]
# # Reduced Model
# ## Backwards stepwise feature pruning

# %%
backward_X = df_train[training_cols]
backward_x_cols = list(backward_X.columns)
backward_y = df_train['logerror']
backwards_test = backward_regression(backward_X, backward_y, verbose = True)
# Out:
# Feature Dropped: regionidcity_113576.0 (p = 0.969)
# Feature Dropped: regionidcity_45457.0 (p = 0.959)
# Feature Dropped: regionidcity_46178.0 (p = 0.964)
# Feature Dropped: regionidcity_40110.0 (p = 0.960)
# Feature Dropped: regionidcity_25459.0 (p = 0.955)
# Feature Dropped: regionidcity_15554.0 (p = 0.971)
# Feature Dropped: regionidcity_33727.0 (p = 0.946)
# Feature Dropped: heatingorsystemtypeid_13.0 (p = 0.944)
# Feature Dropped: propertycountylandusecode_1310 (p = 0.942)
# Feature Dropped: regionidcity_53571.0 (p = 0.940)
# Feature Dropped: regionidcity_11626.0 (p = 0.937)
# Feature Dropped: regionidcity_34780.0 (p = 0.929)
# Feature Dropped: regionidcity_21412.0 (p = 0.925)
# Feature Dropped: regionidcity_10815.0 (p = 0.919)
# Feature Dropped: regionidcity_25458.0 (p = 0.912)
# Feature Dropped: regionidcity_33612.0 (p = 0.907)
# Feature Dropped: regionidcity_396556.0 (p = 0.893)
# Feature Dropped: regionidcity_33252.0 (p = 0.890)
# Feature Dropped: regionidcity_24435.0 (p = 0.888)
# Feature Dropped: heatingorsystemtypeid_11.0 (p = 0.887)
# Feature Dropped: regionidcity_38980.0 (p = 0.880)
# Feature Dropped: regionidcity_16764.0 (p = 0.875)
# Feature Dropped: regionidcity_37086.0 (p = 0.876)
# Feature Dropped: regionidcity_24174.0 (p = 0.872)
# Feature Dropped: regionidcity_42150.0 (p = 0.857)
# Feature Dropped: regionidcity_26483.0 (p = 0.861)
# Feature Dropped: regionidcity_54053.0 (p = 0.864)
# Feature Dropped: regionidcity_44116.0 (p = 0.862)
# Feature Dropped: regionidcity_16677.0 (p = 0.859)
# Feature Dropped: heatingorsystemtypeid_10.0 (p = 0.849)
# Feature Dropped: regionidcity_18874.0 (p = 0.846)
# Feature Dropped: regionidcity_40081.0 (p = 0.837)
# Feature Dropped: regionidcity_47547.0 (p = 0.824)
# Feature Dropped: regionidcity_32380.0 (p = 0.811)
# Feature Dropped: regionidcity_34543.0 (p = 0.809)
# Feature Dropped: regionidcity_24812.0 (p = 0.807)
# Feature Dropped: regionidcity_32927.0 (p = 0.791)
# Feature Dropped: regionidcity_30187.0 (p = 0.788)
# Feature Dropped: regionidcity_53636.0 (p = 0.792)
# Feature Dropped: regionidcity_39308.0 (p = 0.796)
# Feature Dropped: propertycountylandusecode_0300 (p = 0.785)
# Feature Dropped: regionidcity_44833.0 (p = 0.771)
# Feature Dropped: propertycountylandusecode_0102 (p = 0.770)
# Feature Dropped: regionidcity_34278.0 (p = 0.759)
# Feature Dropped: regionidcity_25271.0 (p = 0.750)
# Feature Dropped: propertycountylandusecode_0111 (p = 0.746)
# Feature Dropped: regionidcity_272578.0 (p = 0.743)
# Feature Dropped: regionidcity_47762.0 (p = 0.745)
# Feature Dropped: regionidcity_24245.0 (p = 0.745)
# Feature Dropped: regionidcity_24384.0 (p = 0.744)
# Feature Dropped: regionidcity_13311.0 (p = 0.741)
# Feature Dropped: regionidcity_52835.0 (p = 0.717)
# Feature Dropped: propertycountylandusecode_0130 (p = 0.698)
# Feature Dropped: bedroomcnt (p = 0.691)
# Feature Dropped: regionidcity_17882.0 (p = 0.687)
# Feature Dropped: regionidcity_12520.0 (p = 0.681)
# Feature Dropped: propertycountylandusecode_1112 (p = 0.663)
# Feature Dropped: heatingorsystemtypeid_1.0 (p = 0.654)
# Feature Dropped: heatingorsystemtypeid_2.0 (p = 0.647)
# Feature Dropped: propertycountylandusecode_0301 (p = 0.635)
# Feature Dropped: regionidcity_46314.0 (p = 0.631)
# Feature Dropped: buildingqualitytypeid (p = 0.622)
# Feature Dropped: regionidcity_16961.0 (p = 0.616)
# Feature Dropped: regionidcity_114828.0 (p = 0.609)
# Feature Dropped: fireplaceflag (p = 0.605)
# Feature Dropped: regionidcity_10608.0 (p = 0.596)
# Feature Dropped: regionidcity_13091.0 (p = 0.593)
# Feature Dropped: regionidcity_47198.0 (p = 0.597)
# Feature Dropped: regionidcity_40009.0 (p = 0.584)
# Feature Dropped: regionidcity_15237.0 (p = 0.579)
# Feature Dropped: regionidcity_27103.0 (p = 0.579)
# Feature Dropped: regionidcity_54970.0 (p = 0.573)
# Feature Dropped: regionidcity_8384.0 (p = 0.569)
# Feature Dropped: regionidcity_54352.0 (p = 0.556)
# Feature Dropped: propertycountylandusecode_73 (p = 0.554)
# Feature Dropped: regionidcity_39076.0 (p = 0.550)
# Feature Dropped: regionidcity_17150.0 (p = 0.542)
# Feature Dropped: lotsizesquarefeet (p = 0.536)
# Feature Dropped: regionidcity_25218.0 (p = 0.528)
# Feature Dropped: regionidcity_12773.0 (p = 0.518)
# Feature Dropped: propertycountylandusecode_0131 (p = 0.517)
# Feature Dropped: propertycountylandusecode_010M (p = 0.558)
# Feature Dropped: propertycountylandusecode_010H (p = 0.686)
# Feature Dropped: propertycountylandusecode_0110 (p = 0.624)
# Feature Dropped: propertycountylandusecode_01HC (p = 0.640)
# Feature Dropped: propertycountylandusecode_0114 (p = 0.647)
# Feature Dropped: regionidcity_53162.0 (p = 0.510)
# Feature Dropped: regionidcity_29189.0 (p = 0.508)
# Feature Dropped: regionidcity_6395.0 (p = 0.513)
# Feature Dropped: regionidcity_10734.0 (p = 0.497)
# Feature Dropped: heatingorsystemtypeid_7.0 (p = 0.496)
# Feature Dropped: regionidcity_45602.0 (p = 0.499)
# Feature Dropped: regionidcity_53655.0 (p = 0.497)
# Feature Dropped: regionidcity_118875.0 (p = 0.495)
# Feature Dropped: unitcnt (p = 0.490)
# Feature Dropped: propertycountylandusecode_010D (p = 0.452)
# Feature Dropped: regionidcity_51861.0 (p = 0.450)
# Feature Dropped: propertycountylandusecode_030G (p = 0.448)
# Feature Dropped: regionidcity_33312.0 (p = 0.447)
# Feature Dropped: regionidcity_114834.0 (p = 0.427)
# Feature Dropped: regionidcity_116042.0 (p = 0.409)
# Feature Dropped: regionidcity_42091.0 (p = 0.395)
# Feature Dropped: regionidcity_37688.0 (p = 0.387)
# Feature Dropped: regionidcity_396054.0 (p = 0.396)
# Feature Dropped: regionidcity_32616.0 (p = 0.403)
# Feature Dropped: regionidcity_12292.0 (p = 0.379)
# Feature Dropped: regionidcity_33836.0 (p = 0.388)
# Feature Dropped: regionidcity_118225.0 (p = 0.377)
# Feature Dropped: regionidcity_45888.0 (p = 0.386)
# Feature Dropped: regionidcity_118914.0 (p = 0.381)
# Feature Dropped: regionidcity_50677.0 (p = 0.387)
# Feature Dropped: regionidcity_118880.0 (p = 0.365)
# Feature Dropped: regionidcity_30908.0 (p = 0.353)
# Feature Dropped: regionidcity_14542.0 (p = 0.340)
# Feature Dropped: regionidcity_113412.0 (p = 0.336)
# Feature Dropped: regionidcity_27491.0 (p = 0.334)
# Feature Dropped: regionidcity_25974.0 (p = 0.325)
# Feature Dropped: regionidcity_13150.0 (p = 0.324)
# Feature Dropped: regionidcity_27110.0 (p = 0.435)
# Feature Dropped: regionidcity_24832.0 (p = 0.317)
# Feature Dropped: regionidcity_13693.0 (p = 0.328)
# Feature Dropped: regionidcity_52842.0 (p = 0.309)
# Feature Dropped: regionidcity_396550.0 (p = 0.305)
# Feature Dropped: regionidcity_17597.0 (p = 0.305)
# Feature Dropped: propertycountylandusecode_1111 (p = 0.289)
# Feature Dropped: regionidcity_118895.0 (p = 0.286)
# Feature Dropped: regionidcity_47695.0 (p = 0.274)
# Feature Dropped: regionidcity_118694.0 (p = 0.271)
# Feature Dropped: regionidcity_25953.0 (p = 0.274)
# Feature Dropped: regionidcity_34037.0 (p = 0.269)
# Feature Dropped: regionidcity_10723.0 (p = 0.256)
# Feature Dropped: regionidcity_26531.0 (p = 0.250)
# Feature Dropped: regionidcity_33840.0 (p = 0.259)
# Feature Dropped: heatingorsystemtypeid_6.0 (p = 0.240)
# Feature Dropped: roomcnt (p = 0.313)
# Feature Dropped: heatingorsystemtypeid_18.0 (p = 0.237)
# Feature Dropped: regionidcity_13716.0 (p = 0.232)
# Feature Dropped: heatingorsystemtypeid_20.0 (p = 0.243)
# Feature Dropped: regionidcity_10241.0 (p = 0.209)
# Feature Dropped: regionidcity_30399.0 (p = 0.205)
# Feature Dropped: regionidcity_10774.0 (p = 0.200)
# Feature Dropped: regionidcity_47019.0 (p = 0.206)
# Feature Dropped: regionidcity_5465.0 (p = 0.214)
# Feature Dropped: regionidcity_14111.0 (p = 0.215)
# Feature Dropped: regionidcity_32753.0 (p = 0.204)
# Feature Dropped: regionidcity_18098.0 (p = 0.180)
# Feature Dropped: regionidcity_56780.0 (p = 0.174)
# Feature Dropped: regionidcity_13232.0 (p = 0.170)
# Feature Dropped: regionidcity_52650.0 (p = 0.166)
# Feature Dropped: regionidcity_32923.0 (p = 0.161)
# Feature Dropped: regionidcity_396053.0 (p = 0.155)
# Feature Dropped: regionidcity_396551.0 (p = 0.158)
# Feature Dropped: regionidcity_26965.0 (p = 0.154)
# Feature Dropped: propertycountylandusecode_1129 (p = 0.161)
# Feature Dropped: regionidcity_14634.0 (p = 0.152)
# Feature Dropped: regionidcity_54722.0 (p = 0.165)
# Feature Dropped: regionidcity_33311.0 (p = 0.165)
# Feature Dropped: regionidcity_26964.0 (p = 0.148)
# Feature Dropped: regionidcity_46298.0 (p = 0.143)
# Feature Dropped: regionidcity_55753.0 (p = 0.151)
# Feature Dropped: regionidcity_25621.0 (p = 0.138)
# Feature Dropped: regionidcity_42967.0 (p = 0.131)
# Feature Dropped: propertycountylandusecode_0108 (p = 0.129)
# Feature Dropped: regionidcity_34636.0 (p = 0.126)
# Feature Dropped: regionidcity_118217.0 (p = 0.124)
# Feature Dropped: regionidcity_48424.0 (p = 0.123)
# Feature Dropped: regionidcity_41673.0 (p = 0.121)
# Feature Dropped: propertycountylandusecode_0103 (p = 0.121)
# Feature Dropped: regionidcity_6021.0 (p = 0.119)
# Feature Dropped: propertycountylandusecode_010E (p = 0.100)
# Feature Dropped: propertycountylandusecode_0104 (p = 0.331)
# Feature Dropped: propertycountylandusecode_010V (p = 0.121)
# Feature Dropped: regionidcity_53027.0 (p = 0.096)
# Feature Dropped: propertycountylandusecode_1321 (p = 0.089)
# Feature Dropped: regionidcity_4406.0 (p = 0.088)
# Feature Dropped: regionidcity_45398.0 (p = 0.079)
# Feature Dropped: regionidcity_51617.0 (p = 0.072)
# Feature Dropped: regionidcity_12447.0 (p = 0.082)
# Feature Dropped: fips_6037.0 (p = 0.112)
# Feature Dropped: regionidcity_54311.0 (p = 0.117)
# Feature Dropped: regionidcity_40227.0 (p = 0.079)
# Feature Dropped: propertycountylandusecode_1333 (p = 0.070)
# Feature Dropped: regionidcity_21395.0 (p = 0.067)
# Feature Dropped: regionidcity_38032.0 (p = 0.063)
# Feature Dropped: propertylandusetypeid_263.0 (p = 0.061)
# Feature Dropped: propertylandusetypeid_248.0 (p = 0.076)
# Feature Dropped: regionidcity_51239.0 (p = 0.052)

# %% [markdown]
# ## Train Reduced Model

# %%
result_red, resids_red, preds_red = run_multiple_regression_ols(df_train, backwards_test, True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     15.09
# Date:                Tue, 12 Apr 2022   Prob (F-statistic):          3.65e-199
# Time:                        09:14:04   Log-Likelihood:                 37447.
# No. Observations:               89670   AIC:                        -7.473e+04
# Df Residuals:                   89589   BIC:                        -7.397e+04
# Df Model:                          80
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              1.2166      0.098     12.361      0.000       1.024       1.409
# calculatedbathnbr                  0.0218      0.009      2.360      0.018       0.004       0.040
# calculatedfinishedsquarefeet      -0.4629      0.052     -8.903      0.000      -0.565      -0.361
# fireplacecnt                    6.727e-07   2.15e-07      3.130      0.002    2.51e-07    1.09e-06
# hashottuborspa                    -0.0107      0.004     -3.013      0.003      -0.018      -0.004
# poolcnt                           -0.0039      0.002     -2.120      0.034      -0.007      -0.000
# structuretaxvaluedollarcnt        -0.0476      0.011     -4.297      0.000      -0.069      -0.026
# landtaxvaluedollarcnt             -0.0038      0.001     -2.724      0.006      -0.007      -0.001
# regionidcity_3491.0                0.2347      0.029      8.050      0.000       0.178       0.292
# regionidcity_5534.0               -0.0113      0.004     -3.017      0.003      -0.019      -0.004
# regionidcity_6822.0                0.1328      0.033      4.074      0.000       0.069       0.197
# regionidcity_10389.0              -0.0372      0.011     -3.494      0.000      -0.058      -0.016
# regionidcity_14906.0              -0.0976      0.044     -2.205      0.027      -0.184      -0.011
# regionidcity_16389.0               0.0569      0.027      2.139      0.032       0.005       0.109
# regionidcity_17686.0              -0.0173      0.008     -2.063      0.039      -0.034      -0.001
# regionidcity_18875.0               0.0684      0.022      3.177      0.001       0.026       0.111
# regionidcity_19177.0              -0.0318      0.009     -3.673      0.000      -0.049      -0.015
# regionidcity_20008.0               0.0176      0.006      2.997      0.003       0.006       0.029
# regionidcity_21778.0               0.0465      0.023      2.060      0.039       0.002       0.091
# propertycountylandusecode_1110     0.0113      0.005      2.125      0.034       0.001       0.022
# propertycountylandusecode_1116    -0.8185      0.104     -7.873      0.000      -1.022      -0.615
# propertycountylandusecode_1117    -0.9402      0.095     -9.882      0.000      -1.127      -0.754
# propertycountylandusecode_1128    -0.4819      0.046    -10.410      0.000      -0.573      -0.391
# propertycountylandusecode_1210     0.3122      0.096      3.268      0.001       0.125       0.499
# propertycountylandusecode_122      0.9946      0.093     10.648      0.000       0.811       1.178
# propertycountylandusecode_1222     0.2920      0.099      2.956      0.003       0.098       0.486
# propertycountylandusecode_135      0.9771      0.097     10.032      0.000       0.786       1.168
# propertycountylandusecode_1410    -0.9762      0.102     -9.548      0.000      -1.177      -0.776
# propertycountylandusecode_1421    -0.9674      0.146     -6.642      0.000      -1.253      -0.682
# propertycountylandusecode_1432    -1.0923      0.146     -7.500      0.000      -1.378      -0.807
# propertycountylandusecode_1720     0.4696      0.117      4.029      0.000       0.241       0.698
# propertycountylandusecode_1722    -2.4598      0.188    -13.078      0.000      -2.828      -2.091
# propertycountylandusecode_34       0.9852      0.093     10.545      0.000       0.802       1.168
# propertycountylandusecode_38       1.2958      0.133      9.712      0.000       1.034       1.557
# propertylandusetypeid_31.0        -1.2247      0.136     -9.015      0.000      -1.491      -0.958
# propertylandusetypeid_246.0       -1.3131      0.132     -9.971      0.000      -1.571      -1.055
# propertylandusetypeid_247.0       -1.0016      0.092    -10.838      0.000      -1.183      -0.820
# propertylandusetypeid_260.0       -0.9939      0.095    -10.425      0.000      -1.181      -0.807
# propertylandusetypeid_261.0       -0.9659      0.092    -10.473      0.000      -1.147      -0.785
# propertylandusetypeid_264.0       -0.6287      0.070     -8.993      0.000      -0.766      -0.492
# propertylandusetypeid_265.0       -0.4819      0.046    -10.410      0.000      -0.573      -0.391
# propertylandusetypeid_266.0       -0.9559      0.092    -10.365      0.000      -1.137      -0.775
# propertylandusetypeid_267.0       -0.4645      0.048     -9.579      0.000      -0.560      -0.369
# propertylandusetypeid_269.0       -0.9758      0.092    -10.578      0.000      -1.157      -0.795
# fips_6059.0                       -1.0029      0.093    -10.741      0.000      -1.186      -0.820
# ==============================================================================
# Omnibus:                    65814.438   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         66268862.386
# Skew:                           2.169   Prob(JB):                         0.00
# Kurtosis:                     136.109   Cond. No.                     1.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.76e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df_train.fireplacecnt.unique()
# Out:
# array([1.04262327e+04, 9.99999330e-01, 6.28642456e-01, 4.79156706e-01,
#        3.95191536e-01, 3.40336232e-01])

# %% [markdown]
# ### Diagnostics

# %%
for column in [i for i in training_cols if i in continuous_cols]:
    
    plot_resid_pred(resids_red, df_train[column])

# %%
normal_probability_plot(result_red, resids_red)

# %% [markdown]
# ## Hypothesis Testing

# %%
sse_full = result_full.ssr
dof_full = result_full.df_resid
sse_reduced = result_red.ssr
dof_reduced = result_red.df_resid
F = scipy.stats.f.ppf(.99, dof_reduced - dof_full, dof_full)

F_star = (sse_reduced - sse_full)/(dof_reduced - dof_full)/(sse_full/dof_full)
print(f'F-statistic Reference Value: {F:.3f}')
print(f'F-star:                      {F_star:.3f}')
# Out:
# F-statistic Reference Value: 1.257
# F-star:                      0.913
